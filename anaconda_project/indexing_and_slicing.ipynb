# %%
import numpy as np

# %%
arr = np.array([[2, 3, 4], [5, 2, 4], [6, 6, 7]])

# %%
arr.shape
# Out:
# (3, 3)

# %%
myarr = np.array([1.4, 1.5, 5.5, 6.7])

# %%
int_arr=myarr.astype(int)
int_arr
# Out:
# array([1, 1, 5, 6])

# %%
arr = np.array([10, 20, 30, 40, 50])
idx = [0, 2, 4]
print(arr[idx])
# Out:
# [10 30 50]

# %%
arr = np.array([10, 20, 30, 40, 50, 60])
yes = arr.reshape((2,3))
yes
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
mask = arr>30
mask
# Out:
# array([False, False, False,  True,  True,  True])
