# %%
a=5
b=6

# %%
a+b
# Out:
# 11

# %%
a*b
# Out:
# 30

# %%
a/b
# Out:
# 0.8333333333333334

# %%
a//b
# Out:
# 0

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
b1 = True
b2 = False

# %%
b1 & b2
# Out:
# False

# %%
b1 or b2
# Out:
# True
