# %% [markdown]
# Working with CSV's

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#       Name   School  Marks
# 0   Aniket       kv     78
# 1     Alek       st     84
# 2     Ashu      hub     59
# 3  Chandan   stmary     45
# 4      Dev  stpeter     78
# 5     Abhi     sans     98
# 6      Ani     audi     63
# 7     Udit     aghi     55

# %%
df = df[df['Marks']>60]

# %%
df
# Out:
#      Name   School  Marks
# 0  Aniket       kv     78
# 1    Alek       st     84
# 4     Dev  stpeter     78
# 5    Abhi     sans     98
# 6     Ani     audi     63

# %%
df.to_csv("data_updated.csv", index=False)

# %%
df = pd.read_json("data.json")

# %% [markdown]
# df
