# %%
x=5
if(x>3):
    print("X is greater")
else:
    print("X is smaller")
# Out:
# X is greater

# %%
a=41
if(a>50):
    print("a is greater than 50")
elif(a>40):
    print("a is greater then 40")
elif(a>30):
    print("a is greater then 30")
else:
    print("a is smaller")
# Out:
# a is greater then 40
